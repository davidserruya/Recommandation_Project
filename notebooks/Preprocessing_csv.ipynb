# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ratings.csv')

# %%
df.head()
# Out:
#    UserId  MovieId  Rating
# 0       2        1     3.5
# 1       3        1     4.0
# 2       4        1     3.0
# 3       5        1     4.0
# 4       8        1     4.0

# %%
threshold = 1500

filter_movies = df['MovieId'].value_counts() >= threshold
filter_movies = filter_movies[filter_movies].index.tolist()

filter_users = df['UserId'].value_counts() > threshold
filter_users = filter_users[filter_users].index.tolist()

df_new = df[(df['MovieId'].isin(filter_movies)) & (df['UserId'].isin(filter_users))]

print('The original number of movies:\t{}'.format(len(df['MovieId'].unique())))
print('The new number of movies:\t{}'.format(len(df_new['MovieId'].unique())))

print('The original number of users:\t{}'.format(len(df['UserId'].unique())))
print('The new number of users:\t{}'.format(len(df_new['UserId'].unique())))

print('The original data frame shape:\t{}'.format(df.shape))
print('The new data frame shape:\t{}'.format(df_new.shape))
# Out:
# The original number of movies:	14196
# The new number of movies:	2825
# The original number of users:	120620
# The new number of users:	758
# The original data frame shape:	(23019525, 3)
# The new data frame shape:	(982568, 3)

# %%
rating_mean = pd.DataFrame(df_new[['MovieId', 'Rating']].groupby('MovieId')['Rating'].mean())

# %%
movies = pd.read_csv('movies_affiche_clean_final.csv')
sql = pd.read_csv('db_sql.csv')

# %%
movies.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
movies.head()
# Out:
#    MovieId                        Title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                             Genres  Year  \
# 0  ['Adventure|Animation|Children|Comedy|Fantasy']  1995
# 1                   ['Adventure|Children|Fantasy']  1995
# 2                               ['Comedy|Romance']  1995
# 3                         ['Comedy|Drama|Romance']  1995
# 4                                       ['Comedy']  1995
#
#                                             Synopsis  RatingMean  \
# 0  A cowboy doll is profoundly threatened and jea...    3.887861
# 1  Four teenagers are sucked into a magical video...    3.240917
# 2  John and Max resolve to save their beloved bai...    3.107356
# 3  Based on Terry McMillan's novel, this film fol...    2.831447
# 4  George Banks must deal not only with his daugh...    3.027098
#
#                                              Affiche
# 0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1  https://m.media-amazon.com/images/M/MV5BMmM1ZT...
# 2  https://m.media-amazon.com/images/M/MV5BMjQxM2...
# 3  https://m.media-amazon.com/images/M/MV5BYzcyMD...
# 4  https://m.media-amazon.com/images/M/MV5BOTEyNz...

# %%
sql.rename(columns=dict(zip(sql.columns, [i[0].capitalize() + i[1:] for i in sql.columns])), inplace=True)

# %%
sql.head()
# Out:
#    MovieId                        Title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                             Genres  Year  \
# 0  ['Adventure|Animation|Children|Comedy|Fantasy']  1995
# 1                   ['Adventure|Children|Fantasy']  1995
# 2                               ['Comedy|Romance']  1995
# 3                         ['Comedy|Drama|Romance']  1995
# 4                                       ['Comedy']  1995
#
#                                             Synopsis  \
# 0  A cowboy doll is profoundly threatened and jea...
# 1  Four teenagers are sucked into a magical video...
# 2  John and Max resolve to save their beloved bai...
# 3  Based on Terry McMillan's novel, this film fol...
# 4  George Banks must deal not only with his daugh...
#
#                                              Affiche
# 0  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 2  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 3  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 4  https://m.media-amazon.com/images/M/MV5BMDU2ZW...

# %%
movie_idx = list(df_new['MovieId'].unique())

# %%
movies_new = movies.set_index('MovieId').loc[movie_idx].reset_index()

# %%
movies_new['RatingMean'] = list(rating_mean['Rating'])

# %%
movies_new
# Out:
#       MovieId                              Title  \
# 0           1                          Toy Story
# 1           2                            Jumanji
# 2           3                   Grumpier Old Men
# 3           4                  Waiting to Exhale
# 4           5        Father of the Bride Part II
# ...       ...                                ...
# 2820   188301               Ant-Man and the Wasp
# 2821   189333      Mission: Impossible - Fallout
# 2822   192803                  Bohemian Rhapsody
# 2823   194448                         Green Book
# 2824   195159  Spider-Man: Into the Spider-Verse
#
#                                                Genres  Year  \
# 0     ['Adventure|Animation|Children|Comedy|Fantasy']  1995
# 1                      ['Adventure|Children|Fantasy']  1995
# 2                                  ['Comedy|Romance']  1995
# 3                            ['Comedy|Drama|Romance']  1995
# 4                                          ['Comedy']  1995
# ...                                               ...   ...
# 2820       ['Action|Adventure|Comedy|Fantasy|Sci-Fi']  2018
# 2821                    ['Action|Adventure|Thriller']  2018
# 2822                                        ['Drama']  2018
# 2823                                 ['Comedy|Drama']  2018
# 2824            ['Action|Adventure|Animation|Sci-Fi']  2018
#
#                                                Synopsis  RatingMean  \
# 0     A cowboy doll is profoundly threatened and jea...    3.947592
# 1     Four teenagers are sucked into a magical video...    3.025381
# 2     John and Max resolve to save their beloved bai...    2.718663
# 3     Based on Terry McMillan's novel, this film fol...    2.391129
# 4     George Banks must deal not only with his daugh...    2.599125
# ...                                                 ...         ...
# 2820  Scott Lang and Hope Van Dyne are dragged into ...    3.327381
# 2821  Ethan Hunt and his IMF team, along with some f...    3.534591
# 2822  The story of the legendary British rock band Q...    3.509740
# 2823  A working-class Italian-American bouncer becom...    3.556000
# 2824  Teen Miles Morales becomes the Spider-Man of h...    3.873288
#
#                                                 Affiche
# 0     https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1     https://m.media-amazon.com/images/M/MV5BMmM1ZT...
# 2     https://m.media-amazon.com/images/M/MV5BMjQxM2...
# 3     https://m.media-amazon.com/images/M/MV5BYzcyMD...
# 4     https://m.media-amazon.com/images/M/MV5BOTEyNz...
# ...                                                 ...
# 2820  https://i.ibb.co/svCHzsj/image-non-disponible.png
# 2821  https://i.ibb.co/svCHzsj/image-non-disponible.png
# 2822  https://i.ibb.co/svCHzsj/image-non-disponible.png
# 2823  https://i.ibb.co/svCHzsj/image-non-disponible.png
# 2824  https://i.ibb.co/svCHzsj/image-non-disponible.png
#
# [2825 rows x 7 columns]

# %%
sql_new = sql.set_index('MovieId').loc[movie_idx].reset_index()

# %%
sql_new
# Out:
#       MovieId                              Title  \
# 0           1                          Toy Story
# 1           2                            Jumanji
# 2           3                   Grumpier Old Men
# 3           4                  Waiting to Exhale
# 4           5        Father of the Bride Part II
# ...       ...                                ...
# 2820   188301               Ant-Man and the Wasp
# 2821   189333      Mission: Impossible - Fallout
# 2822   192803                  Bohemian Rhapsody
# 2823   194448                         Green Book
# 2824   195159  Spider-Man: Into the Spider-Verse
#
#                                                Genres  Year  \
# 0     ['Adventure|Animation|Children|Comedy|Fantasy']  1995
# 1                      ['Adventure|Children|Fantasy']  1995
# 2                                  ['Comedy|Romance']  1995
# 3                            ['Comedy|Drama|Romance']  1995
# 4                                          ['Comedy']  1995
# ...                                               ...   ...
# 2820       ['Action|Adventure|Comedy|Fantasy|Sci-Fi']  2018
# 2821                    ['Action|Adventure|Thriller']  2018
# 2822                                        ['Drama']  2018
# 2823                                 ['Comedy|Drama']  2018
# 2824            ['Action|Adventure|Animation|Sci-Fi']  2018
#
#                                                Synopsis  \
# 0     A cowboy doll is profoundly threatened and jea...
# 1     Four teenagers are sucked into a magical video...
# 2     John and Max resolve to save their beloved bai...
# 3     Based on Terry McMillan's novel, this film fol...
# 4     George Banks must deal not only with his daugh...
# ...                                                 ...
# 2820  Scott Lang and Hope Van Dyne are dragged into ...
# 2821  Ethan Hunt and his IMF team, along with some f...
# 2822  The story of the legendary British rock band Q...
# 2823  A working-class Italian-American bouncer becom...
# 2824  Teen Miles Morales becomes the Spider-Man of h...
#
#                                                 Affiche
# 0     https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 1     https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 2     https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 3     https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 4     https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# ...                                                 ...
# 2820  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 2821  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 2822  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 2823  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
# 2824  https://m.media-amazon.com/images/M/MV5BMDU2ZW...
#
# [2825 rows x 6 columns]

# %%
print(df_new.shape)
print(movies_new.shape)
print(sql_new.shape)
# Out:
# (982568, 3)
# (2825, 7)
# (2825, 6)

# %%
df_new.to_csv('ratings_final.csv', index=False)

# %%
movies_new.to_csv('movies_affiche_final.csv', index=False)

# %%
sql_new.to_csv('db_sql_final.csv', index=False)
